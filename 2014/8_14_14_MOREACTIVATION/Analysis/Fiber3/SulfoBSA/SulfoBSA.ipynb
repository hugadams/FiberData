# %% [markdown]
# # ~/Dropbox/FiberData/2014/8_14_14_MOREACTIVATION/Analysis

# %%
import os.path as op
from pyuvvis import TimeSpectra, examples_dir
from pyuvvis.plotting import six_plot

import plotly.plotly as py
import plotly.tools as tls
creds = tls.get_credentials_file()
user, api_key, tokens = creds['username'], creds['api_key'], creds['stream_ids']
py.sign_in(user, api_key)

nb = op.join(examples_dir, 'NBCONFIG.ipynb')
# %run $nb
# Out:
# Populating the interactive namespace from numpy and matplotlib
# <style>
# #notebook_panel { /* main background */
#     background: #333;
#     color: #f6f6f6;
# }
#
#
# div #notebook { /* centre the content */
#     background: #FFFFF0;  /* IVORY */
#     color: #333;
#     width: 115ex;
#     margin: auto;
#     padding-left: 1em;
#     padding-right: 1em;
#     padding-top: 2ex;
# }
#
#
# div.text_cell_render {  /*Markdown cells */
#     font-family: Computer Modern Roman;
# }
#
# /* remove big margins around title */
# div.text_cell_render.border-box-sizing.rendered_html {
#     margin: 0; /*What is this */
#     padding: 0.05; /*Spacing between cells*/
#     margin-left: 1ex;
# }
# div.cell.text_cell.border-box-sizing {
#     margin: 0;
#     padding: 0.05;
# }
#
# .rendered_html h1 {
#     margin: 0;
#     padding: 0;
# }
# .rendered_html h2 {
#     margin: 0;
#     padding: 0;
# }
# .rendered_html h3 {
#     margin: 0;
#     padding: 0;
# }
#
# /* Width of all cells */
# div.cell { /* set cell width to about 80 chars */
#     width: 55em;
#
# }
#
# /* Set font of coding cells (DONT KNOW WHY BUT NEED THIS) */
# .CodeMirror {
#     /* Preferred font is bold sawasdee, but here are backups */
#     font-family: "Sawasdee", "Lucida Sans Typewriter","Lucida Typewriter",
#          "Lucida Typewriter", "Courier New", Courier, monospace;;
#     font-size: normal;
#     font-weight: 700;
# }
#
# div.cell.code_cell { /* Total code cell, in and out */
#     background: #FFFFF0;
#     border: none;
#     padding-top: 1ex;
# }
#
# div.input_area { /* box around box with code ??? */
#     border: none;
#     background: #f5f5f5;
#     border: 1px solid #fff;
#     border-radius: 10px;
#     padding-top: 0.5ex;
#     padding-bottom: 0.5ex;
#     padding-left: 0.5em;
# }
#
# div.input { /* box with code */
# }
#
#
# div.prompt { /* remove In/Out prompt */
#     display: none;
# }
#
# div.output_subarea { /* remove margin in front of output */
#     border: none;
# }
#
# div.cell.border-box-sizing.code_cell.running {
#     /* draw red dotted border around running cells */
#     border: 3px dotted #f33;
# }
#
# /* header colours and fonts */
# h1 { color: #444; }
# h2 { color: #444; font-style: oblique}
# h3 { color: #0000A0; font-weight: normal}
# h4 { color: #444; font-weight: oblique; font-size: large}
#
#
# </style>

# %% [markdown]
# - **Directory:** Fiber3/SulfoBSA
#
# - **Root:** ~/Dropbox/FiberData/2014/8_14_14_MOREACTIVATION/Analysis
#
# - **Created:** 2014-08-16 23:34:05
#
# - **Spectra:** <font color='orange'>**247**</font>
#
# - **Tstart:** 2014-08-15 18:08:37
#
# - **Tfinal:** 2014-08-15 20:26:52
#
# - **$\Delta$T:** 2:18:15

# %% [markdown]
# ### DIRECTIONS:

# %% [markdown]
# **In the cell below, toggle <font color='blue'>INTERACTIVE</font> to switch between matplotlib and plotly plots.  Choose your desired <font color='blue'>INTERVAL</font> unit, and I'd recommend setting  <font color='red'>SAMPLE_BY</font> if the dataset is over 200 curves.  In <font color='blue'>SLICE THE DATA</font>, set time slices and a simple description of each data subset, then run the cells below.  Enable <font color='green'>EXCLUDE SHORT</font> to ignore wavelengths under 520nm**

# %%
INTERACTIVE = True 
INTERVAL = 'm' #h, m, s, d
SAMPLE_BY = 1 #2,4,10 etc...
EXCLUDE_SHORT = 590.0 # Exclude wavelengths under 525nm

def six_plot_inter(*args, **kwargs):
    """ Interactive six_plot_inter """
    f = six_plot(*args, **kwargs)
    if INTERACTIVE:
        fname = op.join('~/Dropbox/FiberData/2014/8_14_14_MOREACTIVATION/Analysis/Fiber3/SulfoBSA', kwargs.pop('title', ''))
        fname=fname.replace('/', '_').lstrip('_')
        py.iplot_mpl(f, 
                     filename = fname,
                     overwrite=True,
                     resize=False, 
          #           world_readable=False,
                      height=650,
                      update=_pyupdate) #Overwrite some mpl-conversion settings

# %% [markdown]
# ### FULL DATA

# %%
ts = TimeSpectra.from_csv('SulfoBSA_cropped.csv', index_col=0)
ts = ts.ix[:, ::SAMPLE_BY]
if EXCLUDE_SHORT:
    ts = ts.ix[float(EXCLUDE_SHORT)::, :]
ts.reference = 0
ts.specunit = 'nm'
ts = ts.as_interval(INTERVAL)

six_plot_inter(ts, title='Full Data %.2f-%.2f%s' % (ts.columns[0], ts.columns[-1], INTERVAL), striplegend=True)
# Out:
# WARNING:pyuvvis.plotting.basic_plots:Spectrum does not have subtracted baseline; could affect result in specious absorbance data.
# WARNING:pyuvvis.plotting.basic_plots:Recomputing area from shape (261, 247) to (1, 247)
# WARNING:pyuvvis.plotting.basic_plots:areaplot() forcing transpose on None for plotting
# WARNING:pyuvvis.plotting.basic_plots:Spectrum does not have subtracted baseline; could affect result in specious absorbance data.
# <iframe id="igraph" scrolling="no" style="border:none;"seamless="seamless" src="https://plot.ly/~reeveslab/384" height="650" width="100%"></iframe>

# %% [markdown]
# ### SLICE THE DATA

# %%
SLICES = ( 
          (16,26, 'BSA PBS'),  
          (31,48, 'BSA MES'), 
          (50,66, 'BSA elution in MES then PBS'),
          (87,107, 'Activation'),
          (111,129, 'Covalent BSA in MES'),
          (127, 136, 'Elution')
            )

INTERACTIVE = False #Static plots from here down

# %% [markdown]
# **(Add longer description of SLICES here if desired)**

# %%
for (start, end, desc) in SLICES:
    if start == '::':
        start = ts.columns[0]
    elif end == '::':
        end = ts.columns[-1]        
    ts_slice = ts.iloc[:, start:end]
    ts_slice.reference = 0 #Should be automatic when slicing?
    six_plot_inter(ts_slice, title="Timeslice: %.2f-%.2f%s (%s)" % (start, end, INTERVAL, desc))
# Out:
# WARNING:pyuvvis.plotting.basic_plots:Spectrum does not have subtracted baseline; could affect result in specious absorbance data.
# WARNING:pyuvvis.plotting.basic_plots:Recomputing area from shape (261, 19) to (1, 19)
# WARNING:pyuvvis.plotting.basic_plots:areaplot() forcing transpose on None for plotting
# WARNING:pyuvvis.plotting.basic_plots:Spectrum does not have subtracted baseline; could affect result in specious absorbance data.
# WARNING:pyuvvis.plotting.basic_plots:Spectrum does not have subtracted baseline; could affect result in specious absorbance data.
# WARNING:pyuvvis.plotting.basic_plots:Recomputing area from shape (261, 32) to (1, 32)
# WARNING:pyuvvis.plotting.basic_plots:areaplot() forcing transpose on None for plotting
# WARNING:pyuvvis.plotting.basic_plots:Spectrum does not have subtracted baseline; could affect result in specious absorbance data.
# WARNING:pyuvvis.plotting.basic_plots:Spectrum does not have subtracted baseline; could affect result in specious absorbance data.
# WARNING:pyuvvis.plotting.basic_plots:Recomputing area from shape (261, 30) to (1, 30)
# WARNING:pyuvvis.plotting.basic_plots:areaplot() forcing transpose on None for plotting
# WARNING:pyuvvis.plotting.basic_plots:Spectrum does not have subtracted baseline; could affect result in specious absorbance data.
# WARNING:pyuvvis.plotting.basic_plots:Spectrum does not have subtracted baseline; could affect result in specious absorbance data.
# WARNING:pyuvvis.plotting.basic_plots:Recomputing area from shape (261, 37) to (1, 37)
# WARNING:pyuvvis.plotting.basic_plots:areaplot() forcing transpose on None for plotting
# WARNING:pyuvvis.plotting.basic_plots:Spectrum does not have subtracted baseline; could affect result in specious absorbance data.
# WARNING:pyuvvis.plotting.basic_plots:Spectrum does not have subtracted baseline; could affect result in specious absorbance data.
# WARNING:pyuvvis.plotting.basic_plots:Recomputing area from shape (261, 33) to (1, 33)
# WARNING:pyuvvis.plotting.basic_plots:areaplot() forcing transpose on None for plotting
# WARNING:pyuvvis.plotting.basic_plots:Spectrum does not have subtracted baseline; could affect result in specious absorbance data.
# WARNING:pyuvvis.plotting.basic_plots:Spectrum does not have subtracted baseline; could affect result in specious absorbance data.
# WARNING:pyuvvis.plotting.basic_plots:Recomputing area from shape (261, 16) to (1, 16)
# WARNING:pyuvvis.plotting.basic_plots:areaplot() forcing transpose on None for plotting
# WARNING:pyuvvis.plotting.basic_plots:Spectrum does not have subtracted baseline; could affect result in specious absorbance data.

# %% [markdown]
# ### COPY OF SPECTROMETER NOTES FROM REPORT

# %% [raw]
# Similiar in profile to fiber 6; nothing indicates marring of any sort.
# Steps:
# • As with fiber 6, put in PBS and early data showed rising.
# – This time, rinse was permanently up
# • Added 220uL BSA in PBS
# – Some binding, so fiber is sensitive , at least 40 counts in first few minutes. Maybe
# a little more binding than I’m comfortable with. Will see how much elutes and how
# sensitve fiber is for comparison.
# • Pumped PBS
# – Not much elution; overall about 50 counts out of 2550 or 0.02, so ok...
# • Pumped MES
# – Noticed drop around 560-575 while longer wavelengths increased. This makes area
# change from pumping MES look artificially small.
# • Added 220 BSA (in pbs)
# – Much larger signal than had seen with last fiber (fiber 6) so this is more in line with
# what I had expected.
# • Pumped PBS
# – ODD . At long wavelengths, mostly eluted back to original level; however almost no
# spectral chang at λ < 590nm. Why is the fiber like this?
# • Added ph10.01 buffer so that fiber was in half buffer/half pbs
# – Adding more ph10 didn’t make much difference.
# • What can be going on? Why would fiber rise one way from BSA but not rinse off in the same
# spots?
# • Transferred to fresh cuvette in MES while data was paused.
# – Jump in signal could mean baseline position change, or that BSA didn’t elute much.
# in any case, at this point, I don’t know if I trust covalent immobilization
# because there might be too much BSA/MES on fiber?
# – Although it eventually dropped off pretty low back to where wanted it after this... WT-
# FWTFWTF? IT’s also in the middle part of the spectrum that didn’t move prior, but
# the BSA region isn’t!
# 1
# • Made 60:12mM EDC:Sulfo as by added 170uL MES to EDC, then transferring to Sulfo. This
# is approximately 107uL EDC 63uL Sulfo, which is close enough to what I need.
# • Added it ; fairly good index change, waited 15 min.
# • Pumped MES (again, odd index behavior, but overall drop so good)
# • Added 220uL BSA in PBS to the overall MES mixture
# – Good signal, especially out at long wavelengths (but wtf short wavelengths) At long
# wavelengths, signal is larger than it was with non-specific binding .
# • Pumped PBS
# – Most change was in lambda less than 600nm range, almost none at long
# wavelengths.
# • Stopped saving data and added 100uL avidin for fun, followed by 2nd drop
# – Fairly large, similar in size to last time, response to avidin in PBS. Considering there’s
# probably substantial BSA on fiber at this point, that’s a good thing. This means
# that while BSA was binding nicely, probably still a lot more room for bining
# if can control deposition electrostatics better.
# Conclusions:
# 1. Weird dispersion in this data makes it difficult to interpret and raw area shouldn’t
# be trusted. λ > 600nm is best region for data; however, this makes me nervous about
# numerically comparing it to others.
# 2. It’s really not clear if BSA came off after MES step; at first didn’t seem too, then was a decent
# drop after sat in MES a while.
# • If bsa on fiber, can’t be sure we’re just crosslinking some BSA to other BSA, right?
# 3. Sulfo-NHS seems compatible in solution, no issues.
# 4. BSA binding (at long wavelengths) was definitly present after activation; compared to 7-24
# F7, I think it probably was more.
# 5. Not in dataset, but lots of avidin binding, indicating that still much more room to add
# proteins.

# %% [markdown]
# ### GWUSPEC SCRIPT PARAMETERS

# %% [markdown]
# - **_fit_regions:** ((345.0, 395.0), (900.0, 1000.0))
# - **_iunits:** [None, 'r', 'a']
# - **_valid_minmax:** (339.0, 1024.0)
# - **bline_fit:** True
# - **git:** False
# - **intvlunit:** s
# - **reference:** 0
# - **specunit:** nm
# - **sub_base:** True
# - **t_end:** None
# - **t_start:** None
# - **uv_ranges:** 8
# - **x_max:** 680.0
# - **x_min:** 430.0

# %% [markdown]
# ### SIX PLOT OPTIONS

# %%
help(six_plot)
# Out:
# Help on function six_plot in module pyuvvis.plotting.multiplots:
#
# six_plot(ts, *plotargs, **plotkwds)
#     Output a matplotlib figure with full spectra, absorbance, area and
#     stripchart.  Figure should be plotly convertable through py.iplot_mpl(fig)
#     assuming one is signed in to plotly through py.sign_in(user, apikey).
#
#     Parameters
#     -----------
#     title : str
#         Title of the overall figure
#
#     striplegend : bool (False)
#         Add a legend to the strip chart
#
#     colormap : string ('jet')
#         Colormap applied to full and absorbance spectra.
#         'Jet' is applid to strip chart regardless.
#
#     tight_layout: bool (False)
#         Calls mpl.fig.tight_layout()

# %% [markdown]
# <hr>
# <br>
#
#
# <div style="float:left; \">
#     <img src="https://avatars0.githubusercontent.com/u/1972276?s=460"
#  align=left; text-align:center; style="float:left; margin-left: 5px; margin-top: -25px; width:150px; height:150px" />
# </div>
#
# <div style="float:left; \"><a href="https://github.com/hugadams">
#     <img src="https://assets-cdn.github.com/images/modules/logos_page/GitHub-Mark.png"
#  align=left; text-align:center; style="float:left; margin-left: 25px; margin-top: -25px; width:75px; height:75px" />
# </div>
#
#
# <div style="float:left; \"><a href="https://twitter.com/hughesadam87">
#     <img src="http://paymentmagnates.com/wp-content/uploads/2014/04/twitter-icon.png"
#  align=left; text-align:center; style="float:left; margin-left: 25px; margin-top: -25px; width:75px; height:75px" />
# </div>
#
# <div style="float:left; \"><a href="https://www.researchgate.net/profile/Adam_Hughes2?ev=hdr_xprf">
#     <img src="http://www.txhughes.com/images/button-researchgate.png"
#  align=left; text-align:center; style="float:left; margin-left: -175px; margin-top: 55px; width:75px; height:75px" />
# </div>
#
# <div style="float:left; \"><a href="https://www.linkedin.com/profile/view?id=121484744&trk=nav_responsive_tab_profile_picg">
#     <img src="http://smallbusinessesdoitbetter.com/wordpress/wp-content/uploads/li.png"
#  align=left; text-align:center; style="float:left; margin-left: -75px; margin-top: 55px; width:75px; height:75px" />
# </div>
#
# <div style="float:center; \"><a href="http://www.gwu.edu/">
#     <img src="https://raw.githubusercontent.com/hugadams/pyparty/master/pyparty/data/gwu.png"
#  align=center style="float:center; margin-right: 30px; margin-top: -35px; width:335px; height:180px" />
# </div>
#
#
# <h4 style="margin-top:0px;"> This notebook is free for redistribution. If citing, please reference as: </h4>
# - *Hughes, A. (2012). [A Computational Framework for Plasmonic Nanobiosensing](https://www.researchgate.net/publication/236672995_A_Computational_Framework_for_Plasmonic_Nanobiosensing).  Python in Science Conference [SCIPY].*
#
#
# <h3 style="margin-top:30px;"> Questions or Feedback? </h3>
#
# * hugadams@gwmail.gwu.edu
# * twitter:  <a href="https://twitter.com/hughesadam87" target="_blank">@hughesadam87</a>
# * <a href="http://www.gwu.edu/~condmat/CME/reeves.html" target="_blank">Mark Reeves Biophysics Group</a>
#
#
#
#
# <h3 style="margin-top:30px;"> References: </h3>
#
# * [1] : **REF 1**
# * [2] : **REF 2**
#
#
#
#
#
# <h3 style="margin-top:30px;"> Related: </h3>
#
#    * <a href="https://github.com/hugadams/pyparty" target="_blank">pyuvvis: Exploratory Spectral Data Analysis</a>
#    * <a href="https://github.com/hugadams/pyparty" target="_blank">pyparty: Image Analysis of Particles</a>
#    * <a href="http://lorenabarba.com/" target="_blank">Lorena A. Barba (GWU Engineering)</a>
#    * <a href="http://www.youtube.com/watch?v=W7RgkHM-B60" target="_blank">xray: extended arrays for scientific datasets</a>
#
#
#
# <h3 style="margin-top:30px;">Notebook styling ideas:</h3>
#
# * <a href="http://blog.louic.nl/?p=683" target="_blank">Louic's web blog</a>
# * <a href="https://plot.ly/feed" target="_blank">Plotly</a>
# * <a href="http://damon-is-a-geek.com/publication-ready-the-first-time-beautiful-reproducible-plots-with-matplotlib.html" target="_blank">Publication-ready the first time: Beautiful, reproducible plots with Matplotlib</a>
#
# <br>
# <hr>
